# %% [markdown]
# ## Import Libraries and Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
figure, axes = plt.subplots(2,2, figsize=(15,10))

# Label Each Sub Plot Appropriately
ax00 = axes[0][0]
ax01 = axes[0][1]
ax10 = axes[1][1]
ax11 = axes[1][1]

# Define Data Points for first Sub Plot
x00 = [1,2,4,8]
y00 = [2,6,4,9]

# Define Data Points for Second Sub Plot
x01 = [2,6,4,9]
y01 = [1,2,4,8]

ax00.plot(x00,y00)
ax01.plot(x01,y01)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 16)
r = np.linspace(0, 1, 6)
x = np.cos(theta)[:,np.newaxis]*r
y = np.sin(theta)[:,np.newaxis]*r

quiveropts = dict(color='black', headlength=0, pivot='middle', scale=3, linewidth=.5, units='xy', width=.05, headwidth=1) # common options
f, (ax1, ax2) = plt.subplots(1,2, sharex=True, sharey=True)

ax1.quiver(x,y, -y, x, headaxislength=4.5, **quiveropts) # the default
ax2.quiver(x,y, -y, x, headaxislength=0, **quiveropts)

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

x = np.arange(0,2.2,0.2)
y = np.arange(0,2.2,0.2)


X, Y = np.meshgrid(x, y)
u = np.cos(X)*Y
v = np.sin(y)*Y

fig, ax = plt.subplots(figsize=(7,7))
ax.quiver(X,Y,u,v)

ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
ax.axis([-0.2, 2.3, -0.2, 2.3])
ax.set_aspect('equal')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

x = np.arange(0,2.2,0.2)
y = np.arange(0,2.2,0.2)

X, Y = np.meshgrid(x, y)
u = np.cos(X)*Y
v = np.sin(y)*Y

fig, ax = plt.subplots(figsize=(7,7))
ax.quiver(X,Y,u,v, headwidth=1, headlength=0, linewidth=.05, pivot='middle', scale=50)

ax.xaxis.set_ticks([])
ax.yaxis.set_ticks([])
ax.axis([-0.2, 2.3, -0.2, 2.3])
ax.set_aspect('equal')


plt.show()
