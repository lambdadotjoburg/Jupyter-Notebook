# %% [markdown]
# ### Graphing Calculator

# %%
from sympy import *

x, y = symbols('x, y')

plt = plot_implicit(x**2 + y**2 - 4)

axes.set_aspect(1)

# %%
from sympy import *

x, y = symbols('x, y')

plt = plot_implicit(x**2 - y**2 - 4)

axes.set_aspect(1)

# %%
from sympy import *

x, y = symbols('x, y')

plt = plot_implicit(y- x**2 + 4)

axes.set_aspect(1)
