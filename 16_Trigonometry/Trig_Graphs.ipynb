# %% [markdown]
# # Trigonometric Graphs

# %%
# Import appropriate python packages

from numpy import *
import matplotlib.pyplot as plt
import sympy as smp

plt.rcParams['axes.grid'] = True

# %% [markdown]
# ### Define the Union Operation of Two Sets while Maintaining the Order

# %%
def Union(lst1, lst2):
    final_list = list(set(lst1) | set(lst2))
    return sort(final_list)

# %% [markdown]
# ### Define the Domain of the Function

# %%
k=2

x = linspace(0*pi, 2*pi, 1000)

# %% [markdown]
# ### Generate a List for the Ticks along the x-Axis:
#
# #### Step Size of $\pi / 3$ over the interval $(- 2 \pi, 2 \pi )$
# #### Step Size of $\pi / 4$ over the interval $(- 2 \pi, 2 \pi )$
# #### Take the Union of the above lists

# %%
xvalsrads1 = list(arange(0*smp.pi ,2*smp.pi+(smp.pi/6), (smp.pi/6)))
xvalsrads2 = list(arange(0*smp.pi ,2*smp.pi, (smp.pi/4)))

xvalsrads = Union(xvalsrads1,xvalsrads2)

# %% [markdown]
# ### Convert Radian Values in the List above to a List of Corresponding Degrees:
#
# #### Step Size of $30^o$ over the interval $(-360^o, 360^o)$
# #### Step Size of $45^o$ over the interval $(-360^o, 360^o)$
# #### Take the Union of the above lists

# %%
xvalsdegs1 = list(arange(0*smp.pi*(360/(2*smp.pi)), ((2*smp.pi)+(smp.pi/6))*(360/(2*smp.pi)), (smp.pi/6)*(360/(2*smp.pi)) ))
xvalsdegs2 = list(arange(0*smp.pi*(360/(2*smp.pi)), 2*smp.pi*(360/(2*smp.pi)), (smp.pi/4)*(360/(2*smp.pi)) ))

xvalsdegs = Union(xvalsdegs1,xvalsdegs2)

# %% [markdown]
# ### Generate a List for the Ticks along the y-Axis:
#
# #### Step Size of $\frac{\sqrt{3}}{2} $ over the interval $(0, k)$ and $\frac{\sqrt{3}}{2} $ over the interval $(0, -k)$
# #### Step Size of $\frac{\sqrt{2}}{2} $ over the interval $(0, k)$ and $\frac{\sqrt{2}}{2} $ over the interval $(0, -k)$
# #### Step Size of $\frac{1}{2} $ over the interval $(0, k)$ and $\frac{1}{2} $ over the interval $(0, -k)$
# #### Take the Union of the above lists

# %%
def Convert(lst):
    return [ -i for i in lst ]

# %%
yvalspos01 = list(arange(0 , k, smp.sqrt(3)/2))
yvalsneg01 = Convert(yvalspos01)
yvals01 = list(Union(yvalsneg01,yvalspos01))

# %%
yvalspos02 = list(arange(0 , k, smp.sqrt(2)/2))
yvalsneg02 = Convert(yvalspos02)
yvals02 = list(Union(yvalsneg02,yvalspos02))

# %%
yvalspos03 = list(arange(0 , k, 1/2))
yvalsneg03 = Convert(yvalspos03)
yvals03 = list(Union(yvalsneg03,yvalspos03))

# %%
endpoints = [-k, k]

# %%
roots = list(Union(yvals01,yvals02))
halfs = list(Union(yvals03,endpoints))

yvals = list(Union(halfs,roots))

# %% [markdown]
# ### Define the Trigonometric Functions

# %%
def f(x):
    return sin(x)

def g(x):
    return cos(x)

def h(x):
    return tan(x)

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.rcParams['axes.grid'] = True

plt.plot(x, f(x), label=r'$f(x) = \sin(x)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.rcParams['axes.grid'] = True

plt.plot(x, f(x), label=r'$f(x) = \sin(x)$')
plt.plot(x, 2*f(x), label=r'$f(x) = 2 \sin(x)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11, rotation=90)


plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, 2*g(x - pi/4) + 1, label=r'$g(x) = 2 \cos(x-p)+q$')

plt.ylim(-k,k+2)

plt.legend(fontsize=20, loc='lower right')

plt.savefig('trigonometry.jpg')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, g(x), label=r'$g(x) = \cos(x)$')
plt.plot(x, 1/2*g(x), label=r'$g(x) = 1/2  \cos(x)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='lower right')

plt.savefig('trigonometry.jpg')

plt.show()

# %%
fig = plt.figure(figsize=(20,5))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks([-1, -0.5 ,0, 0.5,1], ['-1', '$ 1/2 $' ,0, '$1/2$', '1'])

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.rcParams['axes.grid'] = True

plt.plot(x, h(x), label=r'h(x) = $\tan(x)$')

plt.ylim(-(k+2),k+2)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,5))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks([-2, -1.5, -1, -0.5 ,0, 0.5,1, 1.5, 2], ['-2', '-1.5', '-1', '$ 1/2 $' ,0, '$1/2$', '1', '1.5', '2'])

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.rcParams['axes.grid'] = True

plt.plot(x, h(x), label=r'h(x) = $\tan(x)$')
plt.plot(x, 2*h(x), label=r'h(x) = $2 \tan(x)$')

plt.ylim(-(k+2),k+2)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, -f(x), label=r'$f(x) = -\sin(x)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, -g(x), label=r'$g(x) = -\cos(x)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,5))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks([-1, -0.5 ,0, 0.5,1], ['-1', '$ 1/2 $' ,0, '$1/2$', '1'])

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.ylim(-(k+2),k+2)

plt.plot(x, -h(x), label=r'h(x) = - $\tan(x)$')

plt.legend(fontsize=20, loc='lower right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, g(x) + 1, label=r'$g(x) = \cos(x) + 1$')
plt.plot(x, g(x) + 1/2, label=r'$g(x) = \cos(x) + \frac{1}{2}$')
plt.plot(x, g(x), label=r'$g(x) = \cos(x)$')
plt.plot(x, g(x) - 1/2, label=r'$g(x) = \cos(x) - \frac{1}{2}$')
plt.plot(x, g(x) - 1, label=r'$g(x) = \cos(x) - 1$')

plt.ylim(-(k+1),k+1)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, f(x) + 1, label=r'$g(x) = \sin(x) + 1$')
plt.plot(x, f(x) + 1/2, label=r'$g(x) = \sin(x) + \frac{1}{2}$')
plt.plot(x, f(x), label=r'$g(x) = \sin(x)$')
plt.plot(x, f(x) - 1/2, label=r'$g(x) = \sin(x) - \frac{1}{2}$')
plt.plot(x, f(x) - 1, label=r'$g(x) = \sin(x) - 1$')

plt.ylim(-(k+1),k+1)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks([-1, -0.5 ,0, 0.5,1], ['-1', '$ 1/2 $' ,0, '$1/2$', '1'])

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, h(x) + 1, label=r'$g(x) = \tan(x) + 1$')
plt.plot(x, h(x) + 1/2, label=r'$g(x) = \tan(x) + \frac{1}{2}$')
plt.plot(x, h(x), label=r'$g(x) = \tan(x)$')
plt.plot(x, h(x) - 1/2, label=r'$g(x) = \tan(x) - \frac{1}{2}$')
plt.plot(x, h(x) - 1, label=r'$g(x) = \tan(x) - 1$')

plt.ylim(-(k+2), k+2)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, g(x+pi), label=r'$g(x) = \cos(x+180^o)$')
plt.plot(x, g(x+pi/2), label=r'$g(x) = \cos(x+90^o)$')
plt.plot(x, g(x), label=r'$g(x) = \cos(x)$')
plt.plot(x, g(x-pi/2), label=r'$g(x) = \cos(x-90^o)$')
plt.plot(x, g(x-pi), label=r'$g(x) = \cos(x-180^o)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, f(x+pi), label=r'$f(x) = \sin(x+180^o)$')
plt.plot(x, f(x+pi/2), label=r'$f(x) = \sin(x+90^o)$')
plt.plot(x, f(x), label=r'$f(x) = \sin(x)$')
plt.plot(x, f(x-pi/2), label=r'$f(x) = \sin(x-90^o)$')
plt.plot(x, f(x-pi), label=r'$f(x) = \sin(x-180^o)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks([-1, -0.5 ,0, 0.5,1], ['-1', '$ 1/2 $' ,0, '$1/2$', '1'])

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, h(x+pi/2), label=r'$g(x) = \tan(x+90^o)$')
plt.plot(x, h(x+pi/4), label=r'$g(x) = \tan(x+45^o)$')
plt.plot(x, h(x), label=r'$g(x) = \tan(x)$')
plt.plot(x, h(x-pi/4), label=r'$g(x) = \tan(x-45^o)$')
plt.plot(x, h(x-pi/2), label=r'$g(x) = \tan(x-90^o)$')

plt.ylim(-(k+2), k+2)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, f(x), label=r'$f(x) = \sin(x)$')
plt.plot(x, g(x), label=r'$f(x) = \cos(x)$')

plt.ylim(-k,k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, f(x), label=r'$f(x) = \sin(x)$')
plt.plot(x, f(x+pi/2), label=r'$f(x) = \sin(x+90^o)$')
plt.plot(x, - f(x+pi/2), label=r'$f(x) = - \sin(x+90^o)$')
plt.plot(x, -f(x+pi/2)-1, label=r'$f(x) = - \sin(x+90^o) - 1$')

plt.ylim(-(k+1),k)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=11)
ax.set_yticks(yvals, yvals)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, g(x), label=r'$f(x) = \cos(x)$')
plt.plot(x, g(x-pi/4), label=r'$f(x) = \cos(x-45^o)$')
plt.plot(x, 2*g(x-pi/4), label=r'$f(x) = 2 \cos(x-45^o)$')
plt.plot(x, 2*g(x-pi/4)+1, label=r'$f(x) = 2 \cos(x-45^o) + 1$')

plt.ylim(-k,k+1)

plt.legend(fontsize=20, loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=20, rotation=90)
ax.set_yticks([-2,-1,0,1,2,3,4], [-2,-1,0,1,2,3,4], fontsize=20)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, 2*g(2*x) + 1, label=r'$g(x) = a \cdot \cos(k \cdot x) + q$', ls='-', lw='3')

plt.ylim(-k,k+2)

plt.legend(fontsize=28, loc='lower right')

plt.savefig('trigonometry.jpg')

plt.show()

# %%
fig = plt.figure(figsize=(20,8))

ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(xvalsrads,xvalsdegs, fontsize=20, rotation=90)
ax.set_yticks([-2,-1,0,1,2,3,4], [-2,-1,0,1,2,3,4], fontsize=20)

plt.xlabel("x", loc='right', fontsize=20)
plt.ylabel("y", loc='top', rotation=0, fontsize=20)

plt.plot(x, f(x), label=r'$f(x) = \sin(x)$', ls='-', lw='3')

plt.plot(x, 2*g(x), label=r'$k(x) = 2 \cdot \cos(x)$', ls='-', lw='3')

plt.ylim(-k,k+2)

plt.legend(fontsize=28, loc='upper right')

plt.savefig('intersection.jpg')

plt.show()
