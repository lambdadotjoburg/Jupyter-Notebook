# %%
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt
# from matplotlib.animation import pillowplot

fig = plt.figure()

l, = plt.plot([],[], 'k-')

plt.xlim(-5,5)
plt.ylim(-5,5)

def func(x):
    return np.sin(x)*3


xlist = np.linspace(-5,5,100)
ylist = func(xlist)

l.set_data(xlist, ylist)
plt.show()

# %% [markdown]
# Animating graphs and saving as .gif

# %%
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import PillowWriter

fig = plt.figure()

l, = plt.plot([],[], 'k-')

plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('title')

plt.xlim(-5,5)
plt.ylim(-5,5)

def func(x):
    return np.sin(x)*3


metadata = dict(title='movie', artist='Frank')
writer = PillowWriter(fps=15, metadata=metadata)

xlist = []
ylist = []

with writer.saving(fig, 'sinWave.gif', 100):
    for xval in np.linspace(-5,5,100):
        xlist.append(xval)
        ylist.append(func(xval))
        
        l.set_data(xlist, ylist)
        
        writer.grab_frame()

# %% [markdown]
# Animating graphs and saving as .mp4

# %% [markdown]
# Install an FFMpeg by running the command <code>pip install ffmpeg</code> which is an open source video rendering software and speficy to matplotlib where to find the executable file for this program

# %%
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FFMpegWriter

plt.rcParams['animation.ffmpeg_path'] = 'C:\\Users\\Frank\\ ...'

fig = plt.figure()

l, = plt.plot([],[], 'k-')

plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('title')

plt.xlim(-5,5)
plt.ylim(-5,5)

def func(x):
    return np.sin(x)*3


metadata = dict(title='movie', artist='Frank')
writer = PillowWriter(fps=15, metadata=metadata)

xlist = []
ylist = []

with writer.saving(fig, 'sinWave.mp4', 100):
    for xval in np.linspace(-5,5,100):
        xlist.append(xval)
        ylist.append(func(xval))
        
        l.set_data(xlist, ylist)
        
        writer.grab_frame()
